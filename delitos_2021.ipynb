# %% [markdown]
# <a href="https://colab.research.google.com/github/nagots23/An-lisis-de-delitos-2021/blob/main/delitos_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# Leer archivo

# %%
df = pd.read_csv("/content/delitos_2021.csv", sep=";")

# %%
df.head()
# Out:
#            id-mapa  anio    mes        dia       fecha franja       tipo  \
# 0  HC-2021-1008202  2021  Enero  Miércoles  06/01/2021     18  Homicidio
# 1  HC-2021-1009094  2021  Enero     Jueves  07/01/2021     10  Homicidio
# 2  HC-2021-1013236  2021  Enero    Domingo  10/01/2021      7  Homicidio
# 3  HC-2021-1014154  2021  Enero      Lunes  11/01/2021      9  Homicidio
# 4  HC-2021-1015476  2021  Enero      Lunes  11/01/2021     21  Homicidio
#
#           subtipo uso_armas             barrio  comuna       latitud  \
# 0  Siniestro Vial       NaN       Constitución     1.0     -34,62761
# 1  Siniestro Vial       NaN          Mataderos     9.0  -34,64972969
# 2  Siniestro Vial       NaN   Parque Chacabuco     7.0  -34,62917196
# 3  Siniestro Vial       NaN      Nueva Pompeya     5.0  -34,63867577
# 4  Siniestro Vial       NaN  Parque Avellaneda     9.0  -34,64771436
#
#        longitud  cantidad
# 0    -58,379146       1.0
# 1  -58,51058958       1.0
# 2  -58,43058079       1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88567 entries, 0 to 88566
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id-mapa    88567 non-null  object
#  1   anio       88567 non-null  int64
#  2   mes        88567 non-null  object
#  3   dia        88567 non-null  object
#  4   fecha      88567 non-null  object
#  5   franja     88567 non-null  object
#  6   tipo       88567 non-null  object
#  7   subtipo    16321 non-null  object
#  8   uso_armas  8472 non-null   object
#  9   barrio     87390 non-null  object
#  10  comuna     87907 non-null  float64
#  11  latitud    88567 non-null  object
#  12  longitud   88567 non-null  object
#  13  cantidad   7299 non-null   float64
# dtypes: float64(2), int64(1), object(11)
# memory usage: 9.5+ MB

# %%
df.shape
# Out:
# (88567, 14)

# %%
df.size
# Out:
# 1239938

# %%
df.isnull().sum()
# Out:
# id-mapa          0
# anio             0
# mes              0
# dia              0
# fecha            0
# franja           0
# tipo             0
# subtipo      72246
# uso_armas    80095
# barrio        1177
# comuna         660
# latitud          0
# longitud         0
# cantidad     81268
# dtype: int64

# %% [markdown]
# Cambiar nombres de columnas

# %%
df.rename(columns={"uso_armas":"uso de armas"})
# Out:
#                id-mapa  anio      mes        dia       fecha franja  \
# 0      HC-2021-1008202  2021    Enero  Miércoles  06/01/2021     18
# 1      HC-2021-1009094  2021    Enero     Jueves  07/01/2021     10
# 2      HC-2021-1013236  2021    Enero    Domingo  10/01/2021      7
# 3      HC-2021-1014154  2021    Enero      Lunes  11/01/2021      9
# 4      HC-2021-1015476  2021    Enero      Lunes  11/01/2021     21
# ...                ...   ...      ...        ...         ...    ...
# 88562  RH-2021-3751758  2021     Mayo     Sábado  08/05/2021     10
# 88563  RH-2021-3768141  2021    Junio     Martes  29/06/2021     21
# 88564  RH-2021-3768589  2021    Junio  Miércoles  30/06/2021     13
# 88565  RH-2021-3783716  2021    Julio     Sábado  31/07/2021      1
# 88566  RH-2021-3807019  2021  Octubre  Miércoles  06/10/2021     14
#
#                         tipo         subtipo uso de armas             barrio  \
# ...

# %%
df.columns
# Out:
# Index(['id-mapa', 'anio', 'mes', 'dia', 'fecha', 'franja', 'tipo', 'subtipo',
#        'uso_armas', 'barrio', 'comuna', 'latitud', 'longitud', 'cantidad'],
#       dtype='object')

# %%
df = df.dropna(subset=['comuna'])

# %%
df.comuna = df.comuna.astype(int)

# %%
df.dtypes
# Out:
# id-mapa       object
# anio           int64
# mes           object
# dia           object
# fecha         object
# franja        object
# tipo          object
# subtipo       object
# uso_armas     object
# barrio        object
# comuna         int64
# latitud       object
# longitud      object
# cantidad     float64
# dtype: object

# %%
df.dia.unique()
# Out:
# array(['Miércoles', 'Jueves', 'Domingo', 'Lunes', 'Martes', 'Viernes',
#        'Sábado', 'jueves', 'martes', 'domingo', 'viernes', 'lunes',
#        'miércoles', 'sábado'], dtype=object)

# %%
df.dia = df.dia.replace({"domingo":"Domingo","lunes":"Lunes","viernes":"Viernes","jueves":"Jueves", "martes":"Martes","sábado":"Sábado","miércoles":"Miércoles"})

# %%
df.dia.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# Tipos de delitos

# %%
df.tipo.unique()
# Out:
# array(['Homicidio', 'Lesiones', 'Robo (con violencia)',
#        'Hurto (sin violencia)'], dtype=object)

# %%
df2 = df.groupby(['mes'])['tipo'].count().reset_index(name='cantidad')
df2
# Out:
#            mes  cantidad
# 0        Abril      6524
# 1       Agosto      7644
# 2    Diciembre      8546
# 3        Enero      7203
# 4      Febrero      6855
# 5        Julio      7304
# 6        Junio      6687
# 7        Marzo      7957
# 8         Mayo      5830
# 9    Noviembre      8453
# 10     Octubre      7665
# 11  Septiembre      7239

# %%
import plotly.io as pio
pio.templates
# Out:
# Templates configuration
# -----------------------
#     Default template: 'plotly'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none']

# %%
fig = px.bar(df2, x='mes', y='cantidad',
             color="cantidad",
             template='gridon',
             labels={'cantidad':'Cantidad de casos', 'mes':"Mes"},
             title='Cantidad de delitos por mes',
             height=400
             )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df3 = df.groupby(['dia'])['tipo'].count().reset_index(name='cantidad')
df3
# Out:
#          dia  cantidad
# 0    Domingo      9754
# 1     Jueves     13248
# 2      Lunes     13153
# 3     Martes     13393
# 4  Miércoles     13344
# 5     Sábado     11330
# 6    Viernes     13685

# %%
fig2 = px.bar(df3, x='dia', y='cantidad',
             color="cantidad",
             template='plotly',
             labels={'cantidad':'Cantidad de casos', 'dia':"Día"},
             title='Cantidad de delitos por día',
             height=400
             )
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df4 = df[(df.tipo == 'Homicidio')]
df4.head()
# Out:
#            id-mapa  anio    mes        dia       fecha franja       tipo  \
# 0  HC-2021-1008202  2021  Enero  Miércoles  06/01/2021     18  Homicidio
# 1  HC-2021-1009094  2021  Enero     Jueves  07/01/2021     10  Homicidio
# 2  HC-2021-1013236  2021  Enero    Domingo  10/01/2021      7  Homicidio
# 3  HC-2021-1014154  2021  Enero      Lunes  11/01/2021      9  Homicidio
# 4  HC-2021-1015476  2021  Enero      Lunes  11/01/2021     21  Homicidio
#
#           subtipo uso_armas             barrio  comuna       latitud  \
# 0  Siniestro Vial       NaN       Constitución       1     -34,62761
# 1  Siniestro Vial       NaN          Mataderos       9  -34,64972969
# 2  Siniestro Vial       NaN   Parque Chacabuco       7  -34,62917196
# 3  Siniestro Vial       NaN      Nueva Pompeya       5  -34,63867577
# 4  Siniestro Vial       NaN  Parque Avellaneda       9  -34,64771436
#
#        longitud  cantidad
# 0    -58,379146       1.0
# 1  -58,51058958       1.0
# 2  -58,43058079       1.0
# ...

# %%
df5 = df4.groupby(['barrio'])['tipo'].count().reset_index(name='Homicidio').sort_values(by='Homicidio', ascending=False)
df5
# Out:
#                barrio  Homicidio
# 3            Barracas         21
# 11             Flores         19
# 2           Balvanera         18
# 16      Nueva Pompeya         10
# 35       Villa Lugano         10
# 27             Retiro          7
# 4            Belgrano          7
# 7           Caballito          7
# 10       Constitución          7
# 19            Palermo          7
# 28           Saavedra          5
# 1             Almagro          5
# 20  Parque Avellaneda          5
# 26           Recoleta          5
# 13          Mataderos          4
# 12            Liniers          3
# 43      Villa Urquiza          3
# 6               Boedo          3
# 23   Parque Patricios          3
# 5                Boca          3
# 18              Nuñez          3
# 33   Villa Del Parque          2
# 34       Villa Devoto          2
# 32       Villa Crespo          2
# 30        San Nicolás          2
# 29      San Cristóbal          2
# 22        Parque Chas          2
# ...

# %%
df6 = df.groupby(['barrio'])['tipo'].count().reset_index()
df7 = df6[df6.tipo >= 200]
df7.head()
# Out:
#       barrio  tipo
# 0  Agronomía   296
# 1    Almagro  3590
# 2  Balvanera  5952
# 3   Barracas  2864
# 4   Belgrano  3030

# %%
df8 = df.groupby(['comuna'])['tipo'].count().reset_index().sort_values(by='tipo', ascending=False)
df8.head()
# Out:
#     comuna  tipo
# 1        1  9447
# 4        4  7796
# 14      14  7785
# 3        3  7579
# 7        7  6767

# %%
df8.tail()
# Out:
#     comuna  tipo
# 2        2  4397
# 10      10  4225
# 6        6  4047
# 11      11  3919
# 0        0   517

# %% [markdown]
# Cantidad de casos por delito

# %%
df9 = df['tipo'].value_counts(ascending=False).reset_index()
df9.head()
# Out:
#                    index   tipo
# 0   Robo (con violencia)  44450
# 1  Hurto (sin violencia)  36159
# 2               Lesiones   7106
# 3              Homicidio    192

# %%
df9.columns = ['Tipo de delito', 'Cantidad']
df9
# Out:
#           Tipo de delito  Cantidad
# 0   Robo (con violencia)     44450
# 1  Hurto (sin violencia)     36159
# 2               Lesiones      7106
# 3              Homicidio       192

# %%
fig3 = px.bar(df9, x='Tipo de delito', y='Cantidad',
             color="Cantidad",
             template='xgridoff',
             labels={'cantidad':'Cantidad de casos', 'dia':"Día"},
             title='Cantidad de delitos por día',
             height=400
             )
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
